# %%
import joblib

logreg_baseline = joblib.load(r"C:\Users\mhdma\OneDrive\Desktop\diabetes-risk-xai\milestones\milestone2_EDA_baseline\models\logreg_baseline.joblib")
scaler = joblib.load(r"C:\Users\mhdma\OneDrive\Desktop\diabetes-risk-xai\milestones\milestone2_EDA_baseline\models\scaler.joblib")
xgb_final_model = joblib.load(r"C:\Users\mhdma\OneDrive\Desktop\diabetes-risk-xai\milestones\milestone2_EDA_baseline\models\xgb_final_model.joblib")

print(type(logreg_baseline))
print(type(scaler))
print(type(xgb_final_model))
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
# <class 'sklearn.preprocessing._data.StandardScaler'>
# <class 'xgboost.sklearn.XGBClassifier'>
